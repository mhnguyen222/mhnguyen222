# %% [markdown]
# <a href="https://colab.research.google.com/github/mhnguyen222/mhnguyen222/blob/main/python_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## importing all the goods

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
## lets get to know the data

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
# ...

# %%
df.size
# Out:
# 5088300

# %%
s_count = (df == '?'). sum()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head(200)
# Out:
#      encounter_id  patient_nbr             race  gender       age weight  \
# 0         2278392      8222157        Caucasian  Female    [0-10)      ?
# 1          149190     55629189        Caucasian  Female   [10-20)      ?
# 2           64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3          500364     82442376        Caucasian    Male   [30-40)      ?
# 4           16680     42519267        Caucasian    Male   [40-50)      ?
# 5           35754     82637451        Caucasian    Male   [50-60)      ?
# 6           55842     84259809        Caucasian    Male   [60-70)      ?
# 7           63768    114882984        Caucasian    Male   [70-80)      ?
# 8           12522     48330783        Caucasian  Female   [80-90)      ?
# 9           15738     63555939        Caucasian  Female  [90-100)      ?
# 10          28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11          36900     77391171  AfricanAmerican    Male   [60-70)      ?
# ...

# %%
print (s_count)
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
## pick any group in this dataset as an initial comparison point: gender and number of lab procedures

# %%
## cleaning

# %%
df = df.rename(columns={'num_lab_procedures': 'Number of Procedures'})

# %%
df = df.rename(columns={'gender': 'Gender'})

# %%
df = df[df['Gender']!= 'Unknown/Invalid']

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  Gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  \
# 0                 1          ?  Pediatrics-Endocrinology
# ...

# %%
## gender and Number of Procedures: compare above group to any other (different) group  - you only need to do one additional group comparison (but you’re welcome to do more comparisons if you feel compelled to do so)

# %%
##Create New DataFrame from Existing DataFrame

# %%
new_df = df [['Gender','Number of Procedures','patient_nbr']].copy()

# %%
new_df.head()
# Out:
#    Gender  Number of Procedures  patient_nbr
# 0  Female                    41      8222157
# 1  Female                    59     55629189
# 2  Female                    11     86047875
# 3    Male                    44     82442376
# 4    Male                    51     42519267

# %%
## mean score / descriptive statistics

# %%
new_df('Number of Procedures').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-883e2a558261> in <cell line: 1>()
# ----> 1 new_df('Number of Procedures').mean()
#
# TypeError: 'DataFrame' object is not callable

# %%
import numpy as np

# %%
new_df['Number of Procedures'].mean()
# Out:
# 43.09590912217604

# %%
## group by

# %%
# prompt: sum Number of procedures for patient_nbr

new_df.groupby('patient_nbr')['Number of Procedures'].sum().head()
# Out:
# patient_nbr
# 135    108
# 378     49
# 729     68
# 774     46
# 927     49
# Name: Number of Procedures, dtype: int64

# %%
new_df.groupby('patient_nbr')['Number of Procedures'].sum().sort_values(ascending = False).head()
# Out:
# patient_nbr
# 88785891    1593
# 1660293     1308
# 84428613    1279
# 43140906    1153
# 97391007    1129
# Name: Number of Procedures, dtype: int64

# %%
df.groupby(['patient_nbr'])

# %%
new_df[['patient_nbr','Number of Procedures']].head()
# Out:
#    patient_nbr  Number of Procedures
# 0      8222157                    41
# 1     55629189                    59
# 2     86047875                    11
# 3     82442376                    44
# 4     42519267                    51

# %%
new_df[['patient_nbr','Number of Procedures']][new_df['patient_nbr'] == 88785891]
# Out:
#         patient_nbr  Number of Procedures
# 38307      88785891                    32
# 40252      88785891                    10
# 40661      88785891                    35
# 44515      88785891                     1
# 45147      88785891                    32
# 45986      88785891                     8
# 50167      88785891                     2
# 50393      88785891                    64
# 50773      88785891                    33
# 51519      88785891                    35
# 52057      88785891                    20
# 53771      88785891                    64
# 54497      88785891                    39
# 60263      88785891                    75
# 62759      88785891                    36
# 63165      88785891                    64
# 65667      88785891                    41
# 67968      88785891                    50
# 71029      88785891                    50
# 72068      88785891                    54
# 74405      88785891                    21
# ...

# %%
new_df.groupby('patient_nbr')['Number of Procedures'].sum().sort_values(ascending = False).head()
# Out:
# patient_nbr
# 88785891    1593
# 1660293     1308
# 84428613    1279
# 43140906    1153
# 97391007    1129
# Name: Number of Procedures, dtype: int64

# %%
## sorted values

# %%
new_df.groupby('patient_nbr').agg({'Gender':'max','Number of Procedures':'sum'}).sort_values('patient_nbr').head()
# Out:
#              Gender  Number of Procedures
# patient_nbr
# 135          Female                   108
# 378          Female                    49
# 729          Female                    68
# 774          Female                    46
# 927          Female                    49

# %%
new_df.groupby('Gender').agg({'Number of Procedures':'mean'})
# Out:
#         Number of Procedures
# Gender
# Female             43.151769
# Male               43.030964

# %%
## bar graph

# %%
df = pd.DataFrame(new_df)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.bar(['Gender'], ['Number of Procedures'], color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Mean Number of Procedures')
plt.title('Mean Number of Procedures by Gender')
plt.show()

# %%
data = dict((map(lambda x: (Number of Procedures[x]), df['new_df'].drop_duplicates().values)))
# Out:
#   File "<ipython-input-86-8decc114ce3f>", line 1
#     data = dict((map(lambda x: (Number of Procedures[x]), df['new_df'].drop_duplicates().values)))
#                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
graph = plt.bar(data.keys(), data.values(), color = 'maroon', width = 0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-aeb4f2e7ece3> in <cell line: 1>()
# ----> 1 graph = plt.bar(data.keys(), data.values(), color = 'maroon', width = 0.4)
#
# NameError: name 'data' is not defined

# %%
df = pd.DataFrame({'Gender': ['A', 'B', 'C'], 'val': [1, 2, 3]}, columns=['Gender', 'Number of Procedures'])

# %%
ax = df.plot.bar(y='Number of Procedures', rot=0)

# %%
grouped_data = new_df.groupby('Gender').agg({'Number of Procedures': 'mean'}).reset_index()

# Plotting a bar chart
plt.figure(figsize=(8, 6))
plt.bar(grouped_data['Gender'], grouped_data['Number of Procedures'], color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Mean Number of Procedures')
plt.title('Mean Number of Procedures by Gender')
plt.show()

# %%
## Summary: I decided to look into the gender and number of procedures base. I first took a look into how many gender/members we are looking at and then investigated with the number of procedures. I wanted to see which type of procdueres were looked at the most and how much. I soon then came across some issues such as null data in the gener category. I dropped the duplicates and soon look at the average for number of procedures which is around 40 for both men and women. I was hoping for something to stand out.
