# %% [markdown]
# <a href="https://colab.research.google.com/github/mhnguyen222/mhnguyen222/blob/main/python_project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##import the goods

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/uip8-fykc.csv?$query=SELECT%0A%20%20%60arrest_key%60%2C%0A%20%20%60arrest_date%60%2C%0A%20%20%60pd_cd%60%2C%0A%20%20%60pd_desc%60%2C%0A%20%20%60ky_cd%60%2C%0A%20%20%60ofns_desc%60%2C%0A%20%20%60law_code%60%2C%0A%20%20%60law_cat_cd%60%2C%0A%20%20%60arrest_boro%60%2C%0A%20%20%60arrest_precinct%60%2C%0A%20%20%60jurisdiction_code%60%2C%0A%20%20%60age_group%60%2C%0A%20%20%60perp_sex%60%2C%0A%20%20%60perp_race%60%2C%0A%20%20%60x_coord_cd%60%2C%0A%20%20%60y_coord_cd%60%2C%0A%20%20%60latitude%60%2C%0A%20%20%60longitude%60%2C%0A%20%20%60geocoded_column%60%2C%0A%20%20%60%3A%40computed_region_f5dn_yrer%60%2C%0A%20%20%60%3A%40computed_region_yeji_bk3q%60%2C%0A%20%20%60%3A%40computed_region_92fq_4b7q%60%2C%0A%20%20%60%3A%40computed_region_sbqj_enih%60%2C%0A%20%20%60%3A%40computed_region_efsh_h5xi%60')

# %%
##Lets get to know my data

# %%
df.head()
# Out:
#    arrest_key              arrest_date  pd_cd                      pd_desc  \
# 0   261209118  2023-01-01T00:00:00.000    109     ASSAULT 2,1,UNCLASSIFIED
# 1   262984267  2023-02-03T00:00:00.000    515  CONTROLLED SUBSTANCE,SALE 3
# 2   263664549  2023-02-15T00:00:00.000    105            STRANGULATION 1ST
# 3   261345231  2023-01-04T00:00:00.000    105            STRANGULATION 1ST
# 4   263536618  2023-02-13T00:00:00.000    109     ASSAULT 2,1,UNCLASSIFIED
#
#    ky_cd        ofns_desc    law_code law_cat_cd arrest_boro  arrest_precinct  \
# 0  106.0   FELONY ASSAULT  PL 1200501          F           K               77
# 1  117.0  DANGEROUS DRUGS  PL 2203901          F           K               73
# 2  106.0   FELONY ASSAULT  PL 1211200          F           K               62
# 3  106.0   FELONY ASSAULT  PL 1211200          F           M               32
# 4  106.0   FELONY ASSAULT  PL 12005WX          F           K               71
#
# ...

# %%
df.tail()
# Out:
#      arrest_key              arrest_date  pd_cd  \
# 995   267256308  2023-04-26T00:00:00.000    503
# 996   262006854  2023-01-16T00:00:00.000    478
# 997   263403792  2023-02-10T00:00:00.000    782
# 998   261291729  2023-01-03T00:00:00.000    792
# 999   262661431  2023-01-28T00:00:00.000    847
#
#                             pd_desc  ky_cd                       ofns_desc  \
# 995  CONTROLLED SUBSTANCE,INTENT TO  117.0                 DANGEROUS DRUGS
# 996  THEFT OF SERVICES, UNCLASSIFIE  343.0  OTHER OFFENSES RELATED TO THEF
# 997        WEAPONS, POSSESSION, ETC  236.0               DANGEROUS WEAPONS
# 998      CRIMINAL POSSESSION WEAPON  118.0               DANGEROUS WEAPONS
# 999  NY STATE LAWS,UNCLASSIFIED FEL  125.0    NYS LAWS-UNCLASSIFIED FELONY
#
#        law_code law_cat_cd arrest_boro  arrest_precinct  ...  x_coord_cd  \
# 995  PL 2201601          F           K               75  ...     1016189
# 996  PL 1651503          M           K               75  ...     1012212
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head(200)
# Out:
#      arrest_key              arrest_date  pd_cd  \
# 0     261209118  2023-01-01T00:00:00.000    109
# 1     262984267  2023-02-03T00:00:00.000    515
# 2     263664549  2023-02-15T00:00:00.000    105
# 3     261345231  2023-01-04T00:00:00.000    105
# 4     263536618  2023-02-13T00:00:00.000    109
# 5     262030390  2023-01-17T00:00:00.000    105
# 6     262362214  2023-01-23T00:00:00.000    105
# 7     264579718  2023-03-04T00:00:00.000    153
# 8     262500981  2023-01-25T00:00:00.000    729
# 9     265281035  2023-03-17T00:00:00.000    244
# 10    262721715  2023-01-30T00:00:00.000    263
# 11    262906326  2023-02-02T00:00:00.000    101
# 12    263347526  2023-02-09T00:00:00.000    397
# 13    266120251  2023-04-04T00:00:00.000    105
# 14    264504888  2023-03-03T00:00:00.000    105
# 15    266637010  2023-04-13T00:00:00.000    339
# 16    267225274  2023-04-25T00:00:00.000    105
# 17    265199935  2023-03-16T00:00:00.000    157
# ...

# %%
#pick any zip code/neighborhood/district in this dataset as an initial comparison point: Arrest Boro

# %%
df = df[df['arrest_boro']!= 'Unknown/Invalid']

# %%
# Question: What neighborhood/boro and what offense is used?

# %%
new_df = df [['arrest_boro','ofns_desc']].copy()

# %%
new_df.head()
# Out:
#   arrest_boro        ofns_desc
# 0           K   FELONY ASSAULT
# 1           K  DANGEROUS DRUGS
# 2           K   FELONY ASSAULT
# 3           M   FELONY ASSAULT
# 4           K   FELONY ASSAULT

# %%
df['arrest_boro'].drop_duplicates()
# Out:
# 0     K
# 3     M
# 5     Q
# 12    B
# 78    S
# Name: arrest_boro, dtype: object

# %%
arrest_boro = {'M': 'Manhattan', 'B': 'Bronx', 'K': 'Brooklyn', 'Q' : 'Queens', 'S': 'Staten Island'}

# %%
new_df['ofns_desc'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0                       FELONY ASSAULT
# 1                      DANGEROUS DRUGS
# 2                       FELONY ASSAULT
# 3                       FELONY ASSAULT
# 4                       FELONY ASSAULT
# 5                       FELONY ASSAULT
# 6                       FELONY ASSAULT
# 7                                 RAPE
# 8                              FORGERY
# 9                             BURGLARY
# 10                               ARSON
# 11        ASSAULT 3 & RELATED OFFENSES
# 12                             ROBBERY
# 13                      FELONY ASSAULT
# 14                      FELONY ASSAULT
# 15                       PETIT LARCENY
# 16                      FELONY ASSAULT
# 17                                RAPE
# 18        ASSAULT 3 & RELATED OFFENSES
# 19                                RAPE
# 20                                RAPE
# 21                             FORGERY
# ...

# %%
#descriptive data

# %%
grouped_data = df.groupby('ofns_desc').mean()
# Out:
# <ipython-input-18-01d25166774f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby('ofns_desc').mean()

# %%
grouped_data = df.groupby('ofns_desc').mean(numeric_only=True)

# %%
print(grouped_data)
# Out:
#                                    arrest_key       pd_cd       ky_cd  \
# ofns_desc
# (null)                           2.693992e+08  450.000000         NaN
# ADMINISTRATIVE CODE              2.639687e+08  878.000000  365.000000
# ARSON                            2.668386e+08  262.777778  114.000000
# ASSAULT 3 & RELATED OFFENSES     2.649708e+08  103.925373  344.000000
# BURGLAR'S TOOLS                  2.688219e+08  209.000000  231.000000
# BURGLARY                         2.655358e+08  241.083333  107.000000
# CANNABIS RELATED OFFENSES        2.612877e+08  578.000000  250.000000
# CRIMINAL MISCHIEF & RELATED OF   2.645911e+08  263.533333  238.555556
# CRIMINAL TRESPASS                2.651962e+08  203.000000  352.000000
# DANGEROUS DRUGS                  2.644519e+08  507.661290  160.774194
# DANGEROUS WEAPONS                2.635059e+08  790.475000  138.650000
# ESCAPE 3                         2.652709e+08  742.000000  237.000000
# ...

# %%
# Remove rows with null values in the 'ofns_desc' column
df_cleaned = df.dropna(subset=['ofns_desc'])

# %%
print(df_cleaned)
# Out:
#      arrest_key              arrest_date  pd_cd  \
# 0     261209118  2023-01-01T00:00:00.000    109
# 1     262984267  2023-02-03T00:00:00.000    515
# 2     263664549  2023-02-15T00:00:00.000    105
# 3     261345231  2023-01-04T00:00:00.000    105
# 4     263536618  2023-02-13T00:00:00.000    109
# 5     262030390  2023-01-17T00:00:00.000    105
# 6     262362214  2023-01-23T00:00:00.000    105
# 7     264579718  2023-03-04T00:00:00.000    153
# 8     262500981  2023-01-25T00:00:00.000    729
# 9     265281035  2023-03-17T00:00:00.000    244
# 10    262721715  2023-01-30T00:00:00.000    263
# 11    262906326  2023-02-02T00:00:00.000    101
# 12    263347526  2023-02-09T00:00:00.000    397
# 13    266120251  2023-04-04T00:00:00.000    105
# 14    264504888  2023-03-03T00:00:00.000    105
# 15    266637010  2023-04-13T00:00:00.000    339
# 16    267225274  2023-04-25T00:00:00.000    105
# 17    265199935  2023-03-16T00:00:00.000    157
# ...

# %%
# Group by 'ofns_desc' and get the unique values along with corresponding 'arrest_boro'
grouped_data = df_cleaned.groupby('ofns_desc')['arrest_boro'].unique()

# %%
print(f"Crime: {ofns_desc}, Arrest Boroughs: {', '.join(arrest_boro_values)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6cf2828143c9> in <cell line: 1>()
# ----> 1 print(f"Crime: {ofns_desc}, Arrest Boroughs: {', '.join(arrest_boro_values)}")
#
# NameError: name 'ofns_desc' is not defined

# %%
# Remove rows with null values in the 'ofns_desc' column
df_cleaned = df.dropna(subset=['ofns_desc'])

# %%
# Group by 'ofns_desc' and get the unique values along with corresponding 'arrest_boro'
grouped_data = df_cleaned.groupby('ofns_desc')['arrest_boro'].unique()

# %%
for ofns_desc, arrest_boro_values in grouped_data.items():
    print(f"Crime: {ofns_desc}, Arrest Boroughs: {', '.join(arrest_boro_values)}")
# Out:
# Crime: (null), Arrest Boroughs: Q, K
# Crime: ADMINISTRATIVE CODE, Arrest Boroughs: Q
# Crime: ARSON, Arrest Boroughs: K, B, Q, S
# Crime: ASSAULT 3 & RELATED OFFENSES, Arrest Boroughs: Q, K, B, M, S
# Crime: BURGLAR'S TOOLS, Arrest Boroughs: K, M
# Crime: BURGLARY, Arrest Boroughs: M, Q, K, B
# Crime: CANNABIS RELATED OFFENSES, Arrest Boroughs: S
# Crime: CRIMINAL MISCHIEF & RELATED OF, Arrest Boroughs: B, Q, M, K, S
# Crime: CRIMINAL TRESPASS, Arrest Boroughs: M, K
# Crime: DANGEROUS DRUGS, Arrest Boroughs: K, M, Q, B, S
# Crime: DANGEROUS WEAPONS, Arrest Boroughs: M, K, Q, B
# Crime: ESCAPE 3, Arrest Boroughs: S
# Crime: FELONY ASSAULT, Arrest Boroughs: K, M, Q, B, S
# Crime: FOR OTHER AUTHORITIES, Arrest Boroughs: M, K, Q
# Crime: FORGERY, Arrest Boroughs: M, B, Q, K
# Crime: FRAUDS, Arrest Boroughs: M, Q, K
# Crime: GAMBLING, Arrest Boroughs: K
# Crime: GRAND LARCENY, Arrest Boroughs: M, Q, B, K, S
# Crime: GRAND LARCENY OF MOTOR VEHICLE, Arrest Boroughs: K, B, Q, M
# ...

# %%
# Count the number of crimes in each borough
borough_counts = df['arrest_boro'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(borough_counts, labels=borough_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Crimes in NYC Boroughs')
plt.show()

# %%
borough_mapping = {'M': 'Manhattan', 'B': 'Bronx', 'K': 'Brooklyn', 'Q': 'Queens', 'S': 'Staten Island'}

# %%
# Replace borough codes with names
df['arrest_boro'] = df['arrest_boro'].map(borough_mapping)

# %%
borough_counts = df['arrest_boro'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(borough_counts, labels=borough_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Crimes in NYC Boroughs')
plt.show()

# %%
##summary: I wanted to take a look at the boroughs and the number and types of crime. In Brooklyn, there was alot of crimes followed by the Bronx and then Manhattan. In line 28, I wanted to explore the types of crimes in which boroughs. I wish to explore more in which are the top crimes.
